# %% [markdown]
# # Pandas

# %%
# def: pandas is used for data maniplutation and analysis.

# 1. pandas is the open source library.
# 2. pandas is designed over the Numpy. [Numpy- numarical python]
# 3. Data Structure in pandas such as Series and Dataframe convert to Numpy  1D and 2D arrays.

# %% [markdown]
# # Important list of operations in pandas

# %%
# 1. Data structures (series, Dataframe)
# 2. Data input and output (Excel, CSV, SQL, JSON)
# 3. Understand the dataset (head(), title(), dtype,...)
# 4. Data Filtering and Indexing of data (loc, iloc, where(),...)
# 5. Handling missing Values (NaN/Null)
# 6. Remove the Duplicate values
# 7. Handle inconsistant data (like Male, M, Ma..)
# 8. Data Transformation (apply()..)
# 9. Aggregation and Grouping Functions
# 10. Time Series releated functions
# 11. Data Visualization

# %% [markdown]
# # 1. Data structures (series, Dataframe)

# %%
pip install pandas

# %%
pd.__version__
