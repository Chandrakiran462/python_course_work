# %% [markdown]
# '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %%
import matplotlib.pyplot as plt
hours = [1,2,3,4,5,6,7,8]
visitors = [50,70,60,80,40,100,120,90]

plt.plot(hours,visitors,
         color = 'red',
         marker = 'o',
         linestyle = '-.',
         linewidth = 1,
         label = 'visitors')
plt.title("Web site visitors")
plt.xlabel('Hours')
plt.ylabel('visitors per hour')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

products = ["smartphone","laptop","watch","earpods","tab"]
sales = [300,400,200,250,150]

plt.bar (products,sales,color = 'blue', edgecolor = 'red',alpha = 0.5)

plt.title("Product sales")
plt.xlabel('Products')
plt.ylabel("sales")

plt.show()

# %%
import matplotlib.pyplot as plt

marks = [59,78,86,71,70,88,64,78,98,93,63,71,96,76,68,90,88,87,85,65,86,60,97,74,80,73,61,82,88,73,87,75,79,97,71,99,87,70,81,70,89,82,78,81,84,87,83,99,80,98]

plt.hist(marks,bins = 25, color = 'lightgreen',edgecolor = 'black')
plt.title('Marks')
plt.xlabel('marks')
plt.ylabel('no. of students')
plt.show()

# %%
import matplotlib.pyplot as plt

ad_spent = [5, 25, 28, 22, 27, 8, 23, 6, 24, 21, 17, 26, 9, 19, 16, 18, 7, 10, 20, 13, 14, 29, 11, 15, 12]
sales = [53, 47, 88, 92, 78, 55, 54, 91, 82, 48, 87, 44, 90, 74, 83, 75, 63, 59, 71, 49, 89, 86, 70, 50, 66]

sizes = list(map(lambda i : i*4,sales))

colors = sales

plt.scatter(ad_spent,sales,
            s = sizes,
            c = colors,
            cmap = "viridis",
            alpha = 0.8,
            edgecolors="black",
            linewidths=1
            )

plt.title("Ads Spent vs sales")
plt.xlabel("Ads_spent")
plt.ylabel("Sales")
plt.colorbar(label = "Sales Value")
plt.grid(True,linestyle = "--",alpha = 0.3)
plt.show()

# %%
brands = ["Apple","Samsung","Xiaomi","Oppo","Vivo","Others"]
market_share = [15,18,22,17,18,10]

plt.pie(market_share,
        labels = brands,
        autopct = "%1.1f%%",
        startangle = 270,
        colors = ["red","green","blue","yellow","orange","brown"],
        explode = [0,0,0.1,0,0,0],
        shadow = True
)

plt.title("Mobile market share")
plt.show()

# %%
marks = [
    [87, 83, 93, 76, 89, 77, 86, 97, 85, 81],
    [67, 68, 62, 60, 63, 61, 66, 64, 55, 56],
    [73, 84, 81, 71, 79, 74, 77, 72, 78, 83],
    [97, 92, 81, 84, 87, 85, 77, 9, 91, 86],
    [93, 94, 71, 95, 70, 86, 97, 84, 91, 53]
]

plt.boxplot(marks,
            patch_artist=True,
            notch=False,
            vert = True,
            labels = ['A','B','C','D','E']
)

plt.title("Marks distribution")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.grid(True,linestyle = '--')
plt.show()
# Out:
# /tmp/ipython-input-664357710.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(marks,

# %%
print(random.sample(range(70,85), 10))
# Out:
# [73, 84, 81, 71, 79, 74, 77, 72, 78, 83]

# %%
import matplotlib.pyplot as plt

days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
visitors = [120, 150, 170, 200, 180, 220, 250]

plt.fill_between(days, visitors,
                 color="skyblue", alpha=0.5,
                 label="Website Visitors")

plt.plot(days, visitors, color="blue", linewidth=2)
plt.title("Website Visitors Over a Week")
plt.xlabel("Day of Week")
plt.ylabel("Number of Visitors")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# ![sphx_glr_plot_colormaps_001.png](data:image/png;base64,...)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [30, 32, 31, 29, 28, 27, 26],
    [33, 34, 32, 30, 29, 28, 27],
    [35, 36, 34, 33, 31, 30, 29],
    [37, 38, 35, 34, 32, 31, 30],
    [36, 37, 34, 32, 31, 30, 29]
])

days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]

weeks = ["Week 1", "Week 2", "Week 3", "Week 4", "Week 5"]

sns.heatmap(data,
            annot=True,
            fmt="1.1f",
            cmap="RdPu",
            linewidths=0.5,
            xticklabels=days,
            yticklabels=weeks)

plt.title("Weekly Temperature Heatmap", fontsize=14, fontweight="bold")
plt.xlabel("Days of the Week")
plt.ylabel("Weeks")
plt.show()
